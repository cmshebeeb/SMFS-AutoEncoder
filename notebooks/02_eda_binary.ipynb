# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### ALLAML

# %%
df1 = pd.read_csv("../data/preprocessed/ALLAML.csv")
df1.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0  -1.017172   0.074113  -0.406939  -0.905824  -0.341244  -1.077075
# 1  -0.249817   0.906262   0.057617   0.837052  -0.087528  -0.025783
# 2   0.394762   1.155907  -2.436312   1.069436  -1.004181  -1.689219
# 3  -0.208891   0.479786   2.225541  -1.585099  -1.356110  -1.256726
# 4   0.087820   0.365365  -0.553640  -0.190798   0.190742   0.746051
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_7121  \
# 0   0.926511   0.147111   1.922802    0.474334  ...     -0.514763
# 1  -0.931584   0.227202   0.233942   -0.106453  ...      0.551561
# 2   0.343441  -1.765056   1.408315   -1.378024  ...      1.735638
# 3   0.782500  -0.623763  -0.347652   -0.295649  ...      0.545019
# 4   0.241580   0.687724  -0.112777    0.676729  ...     -0.063374
#
#    feature_7122  feature_7123  feature_7124  feature_7125  feature_7126  \
# 0     -1.295717      0.019007     -0.064038      0.027578      0.121334
# ...

# %% [markdown]
# It's Binary

# %%
df1.shape
# Out:
# (72, 7130)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Columns: 7130 entries, feature_1 to label
# dtypes: float64(7129), int64(1)
# memory usage: 3.9 MB

# %%
df1.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
#Cheking feature range
df1.iloc[:, :-1].describe().loc[["min", "max"]]
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# min  -3.697799  -3.857791  -3.275771  -2.014115  -2.354607  -2.753818
# max   2.052248   1.530374   2.608596   2.159851   3.006177   1.823957
#
#      feature_7  feature_8  feature_9  feature_10  ...  feature_7120  \
# min  -3.418411  -2.726146  -2.550998   -2.491199  ...     -2.478883
# max   2.717869   1.798984   2.269522    3.431067  ...      2.524621
#
#      feature_7121  feature_7122  feature_7123  feature_7124  feature_7125  \
# min     -1.888554     -3.240723     -1.072096     -3.579736     -1.581287
# max      3.220640      2.628618      5.667381      1.645782      3.400432
#
#      feature_7126  feature_7127  feature_7128  feature_7129
# min     -1.675275     -4.826089     -0.803769     -3.966681
# max      3.898572      2.349441      4.422876      2.701241
#
# [2 rows x 7129 columns]

# %%
import random

random_features = random.sample(list(df1.columns[:-1]), 4)

df1[random_features].hist(figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
#cheking Balance
df1["label"].value_counts()
# Out:
# label
# 1    47
# 2    25
# Name: count, dtype: int64

# %% [markdown]
# ### Prostate_GE

# %%
df2 = pd.read_csv("../data/preprocessed/Prostate_GE.csv")
df2.head()
# Out:
#    feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0   1.075547   1.158362   1.250420   1.000000   1.049218   1.494155
# 1   1.000000   1.000000   1.113943   1.000000   1.230449   1.000000
# 2   1.707570   1.716003   1.000000   1.397940   1.414973   2.225309
# 3   1.176091   1.322219   1.903090   1.041393   1.643453   2.103804
# 4   1.591065   1.397940   1.000000   1.079181   1.707570   2.113943
#
#    feature_7  feature_8  feature_9  feature_10  ...  feature_5958  \
# 0   1.103804   3.238297   1.309630         1.0  ...           1.0
# 1   1.000000   3.219060   1.000000         1.0  ...           1.0
# 2   1.845098   3.556303   1.690196         1.0  ...           1.0
# 3   1.579784   3.407221   1.568202         1.0  ...           1.0
# 4   1.556303   3.754042   1.447158         1.0  ...           1.0
#
#    feature_5959  feature_5960  feature_5961  feature_5962  feature_5963  \
# 0           1.0      1.089905      1.862131      1.000000      1.352183
# ...

# %%
df2['label'].unique()
# Out:
# array([1, 2])

# %% [markdown]
# Binary

# %%
df2.shape
# Out:
# (102, 5967)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Columns: 5967 entries, feature_1 to label
# dtypes: float64(5966), int64(1)
# memory usage: 4.6 MB

# %%
df2.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No Missing Values

# %%
#Cheking feature range
df2.iloc[:, :-1].describe().loc[["min", "max"]]
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# min   1.000000   1.000000   1.000000    1.00000   1.000000   1.000000
# max   1.982271   1.973128   1.939519    1.80618   2.158362   2.419956
#
#      feature_7  feature_8  feature_9  feature_10  ...  feature_5957  \
# min   1.000000   3.094471   1.000000    1.000000  ...      1.000000
# max   1.934498   4.204120   1.968483    1.863323  ...      2.232996
#
#      feature_5958  feature_5959  feature_5960  feature_5961  feature_5962  \
# min      1.000000      1.000000      1.000000      1.041393      1.000000
# max      1.954243      1.919078      2.056905      2.463893      2.146128
#
#      feature_5963  feature_5964  feature_5965  feature_5966
# min      1.000000      1.000000      1.000000       1.00000
# max      2.071882      1.986772      2.238046       1.78533
#
# [2 rows x 5966 columns]

# %%
import random

random_features = random.sample(list(df2.columns[:-1]), 4)

df2[random_features].hist(figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
#cheking Balance
df2["label"].value_counts()
# Out:
# label
# 2    52
# 1    50
# Name: count, dtype: int64

# %% [markdown]
# ### Ydata Profiling

# %%
#ALLAML

from ydata_profiling import ProfileReport

profile = ProfileReport(df1, title="Leukemia Dataset Profile")
profile.to_file("../reports/profiling/leukemia_profile.html")

# %%
#Prostate_GE
from ydata_profiling import ProfileReport

profile = ProfileReport(df2, title="Prostate Dataset Profile")
profile.to_file("../reports/profiling/prostate_profile.html")
